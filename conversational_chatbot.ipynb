# %%
import numpy as np 
import pandas as pd 
import os

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers , activations , models , preprocessing , utils
import pandas as pd

print( tf.version)
# Out:
# <module 'tensorflow._api.v2.version' from '/usr/local/lib/python3.8/dist-packages/tensorflow/_api/v2/version/__init__.py'>

# %% [markdown]
# ## Read the data

# %%
data_path='chatbot-training-dataset'

# %% [markdown]
# since data path is a directory to access it i  have used the following lines to extract it

# %%
import os
data_paths = [os.path.join(pth, f) 
for pth, dirs, files in os.walk(data_path) for f in files]
data_paths
# Out:
# []

# %%
data_path1='chatbot dataset.txt'

# %%
input_texts = []
target_texts = []
with open(data_path1) as f:
    lines = f.read().split('\n')
for line in lines[: min(600, len(lines) - 1)]:
    input_text = line.split('\t')[0]
    target_text = line.split('\t')[1]
    input_texts.append(input_text)
    target_texts.append(target_text)

# %%
print('type of input_text',type(input_text))
print('type of target_texts',type(target_texts))
# Out:
# type of input_text <class 'str'>
# type of target_texts <class 'list'>

# %%
##converting the list in pandas dataframe since input_text,target_text are both are type of list
zippedList =  list(zip(input_texts, target_texts))
lines = pd.DataFrame(zippedList, columns = ['input' , 'output']) 
lines.head()
# Out:
#                              input  \
# 0          What are your interests
# 1  What are your favorite subjects
# 2          What are your interests
# 3              What is your number
# 4              What is your number
#
#                                               output
# 0  I am interested in all kinds of things. We can...
# 1  My favorite subjects include robotics, compute...
# 2  I am interested in a wide variety of topics, a...
# 3                            I don't have any number
# 4                                        23 skiddoo!

# %% [markdown]
# ## Preparing input data for the Encoder

# %%
input_lines = list()
for line in lines.input:
    input_lines.append( line ) 

tokenizer = preprocessing.text.Tokenizer()
tokenizer.fit_on_texts( input_lines ) 
tokenized_input_lines = tokenizer.texts_to_sequences( input_lines ) 

length_list = list()
for token_seq in tokenized_input_lines:
    length_list.append( len( token_seq ))
max_input_length = np.array( length_list ).max()
print( 'Input max length is {}'.format( max_input_length ))

padded_input_lines = preprocessing.sequence.pad_sequences( tokenized_input_lines , maxlen=max_input_length , padding='post' )
encoder_input_data = np.array( padded_input_lines )
print( 'Encoder input data shape -> {}'.format( encoder_input_data.shape ))

input_word_dict = tokenizer.word_index
num_input_tokens = len( input_word_dict )+1
print( 'Number of Input tokens = {}'.format( num_input_tokens))
# Out:
# Input max length is 22
# Encoder input data shape -> (566, 22)
# Number of Input tokens = 518

# %%
encoder_input_data
# Out:
# array([[  4,   3,  12, ...,   0,   0,   0],
#        [  4,   3,  12, ...,   0,   0,   0],
#        [  4,   3,  12, ...,   0,   0,   0],
#        ...,
#        [498, 499,   9, ...,   0,   0,   0],
#        [  9, 207, 208, ...,   0,   0,   0],
#        [510, 192,   5, ...,   0,   0,   0]], dtype=int32)

# %% [markdown]
# ## Preparing input data for the Decoder

# %%
output_lines = list()
for line in lines.output:
    output_lines.append( '<START> ' + line + ' <END>' )  

tokenizer = preprocessing.text.Tokenizer()
tokenizer.fit_on_texts( output_lines ) 
tokenized_output_lines = tokenizer.texts_to_sequences( output_lines ) 

length_list = list()
for token_seq in tokenized_output_lines:
    length_list.append( len( token_seq ))
max_output_length = np.array( length_list ).max()
print( 'Output max length is {}'.format( max_output_length ))

padded_output_lines = preprocessing.sequence.pad_sequences( tokenized_output_lines , maxlen=max_output_length, padding='post' )
decoder_input_data = np.array( padded_output_lines )
print( 'Decoder input data shape -> {}'.format( decoder_input_data.shape ))

output_word_dict = tokenizer.word_index
num_output_tokens = len( output_word_dict )+1
print( 'Number of Output tokens = {}'.format( num_output_tokens))
# Out:
# Output max length is 74
# Decoder input data shape -> (566, 74)
# Number of Output tokens = 1692

# %% [markdown]
# ## Preparing target data for the Decoder

# %%
decoder_target_data = list()
for token_seq in tokenized_output_lines:
    decoder_target_data.append( token_seq[ 1 : ] ) 
    
padded_output_lines = preprocessing.sequence.pad_sequences( decoder_target_data , maxlen=max_output_length, padding='post' )
onehot_output_lines = utils.to_categorical( padded_output_lines , num_output_tokens )
decoder_target_data = np.array(onehot_output_lines )
print( 'Decoder target data shape -> {}'.format( decoder_target_data.shape ))
# Out:
# Decoder target data shape -> (566, 74, 1692)

# %% [markdown]
# ## Defining the Model

# %%
encoder_inputs = tf.keras.layers.Input(shape=( None , ))
encoder_embedding = tf.keras.layers.Embedding( num_input_tokens, 256 , mask_zero=True ) (encoder_inputs)
encoder_outputs , state_h , state_c = tf.keras.layers.LSTM( 256 , return_state=True , recurrent_dropout=0.2 , dropout=0.2 )( encoder_embedding )
encoder_states = [ state_h , state_c ]

decoder_inputs = tf.keras.layers.Input(shape=( None ,  ))
decoder_embedding = tf.keras.layers.Embedding( num_output_tokens, 256 , mask_zero=True) (decoder_inputs)
decoder_lstm = tf.keras.layers.LSTM( 256 , return_state=True , return_sequences=True , recurrent_dropout=0.2 , dropout=0.2)
decoder_outputs , _ , _ = decoder_lstm ( decoder_embedding , initial_state=encoder_states )
decoder_dense = tf.keras.layers.Dense( num_output_tokens , activation=tf.keras.activations.softmax ) 
output = decoder_dense ( decoder_outputs )

model = tf.keras.models.Model([encoder_inputs, decoder_inputs], output )
model.compile(optimizer=tf.keras.optimizers.Adam(), loss='categorical_crossentropy')

model.summary()
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None)]       0           []
#
#  input_2 (InputLayer)           [(None, None)]       0           []
#
#  embedding (Embedding)          (None, None, 256)    132608      ['input_1[0][0]']
#
#  embedding_1 (Embedding)        (None, None, 256)    433152      ['input_2[0][0]']
#
#  lstm (LSTM)                    [(None, 256),        525312      ['embedding[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  lstm_1 (LSTM)                  [(None, None, 256),  525312      ['embedding_1[0][0]',
#                                  (None, 256),                     'lstm[0][1]',
#                                  (None, 256)]                     'lstm[0][2]']
#
#  dense (Dense)                  (None, None, 1692)   434844      ['lstm_1[0][0]']
#
# ==================================================================================================
# Total params: 2,051,228
# Trainable params: 2,051,228
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Training

# %%
model.fit([encoder_input_data , decoder_input_data], decoder_target_data, batch_size=124, epochs=500) 
model.save( 'model.h5' )
# Out:
# Epoch 1/500
# 5/5 [==============================] - 10s 386ms/step - loss: 1.4404
# Epoch 2/500
# 5/5 [==============================] - 2s 387ms/step - loss: 1.4314
# Epoch 3/500
# 5/5 [==============================] - 2s 378ms/step - loss: 1.3479
# Epoch 4/500
# 5/5 [==============================] - 2s 379ms/step - loss: 1.1882
# Epoch 5/500
# 5/5 [==============================] - 2s 380ms/step - loss: 1.1388
# Epoch 6/500
# 5/5 [==============================] - 2s 386ms/step - loss: 1.1212
# Epoch 7/500
# 5/5 [==============================] - 2s 385ms/step - loss: 1.1098
# Epoch 8/500
# 5/5 [==============================] - 2s 382ms/step - loss: 1.1033
# Epoch 9/500
# 5/5 [==============================] - 2s 381ms/step - loss: 1.0975
# Epoch 10/500
# 5/5 [==============================] - 2s 377ms/step - loss: 1.0908
# Epoch 11/500
# 5/5 [==============================] - 2s 393ms/step - loss: 1.0856
# Epoch 12/500
# 5/5 [==============================] - 2s 378ms/step - loss: 1.0785
# Epoch 13/500
# 5/5 [==============================] - 2s 395ms/step - loss: 1.0709
# Epoch 14/500
# 5/5 [==============================] - 2s 391ms/step - loss: 1.0624
# Epoch 15/500
# 5/5 [==============================] - 2s 381ms/step - loss: 1.0539
# Epoch 16/500
# 5/5 [==============================] - 2s 381ms/step - loss: 1.0453
# Epoch 17/500
# 5/5 [==============================] - 2s 381ms/step - loss: 1.0374
# Epoch 18/500
# 5/5 [==============================] - 2s 385ms/step - loss: 1.0300
# Epoch 19/500
# 5/5 [==============================] - 2s 372ms/step - loss: 1.0234
# Epoch 20/500
# 5/5 [==============================] - 2s 378ms/step - loss: 1.0167
# Epoch 21/500
# 5/5 [==============================] - 2s 379ms/step - loss: 1.0100
# Epoch 22/500
# 5/5 [==============================] - 2s 375ms/step - loss: 1.0028
# Epoch 23/500
# 5/5 [==============================] - 2s 387ms/step - loss: 0.9956
# Epoch 24/500
# 5/5 [==============================] - 2s 388ms/step - loss: 0.9884
# Epoch 25/500
# 5/5 [==============================] - 2s 380ms/step - loss: 0.9809
# Epoch 26/500
# 5/5 [==============================] - 2s 382ms/step - loss: 0.9734
# Epoch 27/500
# 5/5 [==============================] - 2s 371ms/step - loss: 0.9660
# Epoch 28/500
# 5/5 [==============================] - 2s 383ms/step - loss: 0.9584
# Epoch 29/500
# 5/5 [==============================] - 2s 383ms/step - loss: 0.9511
# Epoch 30/500
# 5/5 [==============================] - 2s 374ms/step - loss: 0.9437
# Epoch 31/500
# 5/5 [==============================] - 2s 383ms/step - loss: 0.9364
# Epoch 32/500
# 5/5 [==============================] - 2s 379ms/step - loss: 0.9295
# Epoch 33/500
# 5/5 [==============================] - 2s 392ms/step - loss: 0.9223
# Epoch 34/500
# 5/5 [==============================] - 2s 388ms/step - loss: 0.9153
# Epoch 35/500
# 5/5 [==============================] - 2s 384ms/step - loss: 0.9086
# Epoch 36/500
# 5/5 [==============================] - 2s 378ms/step - loss: 0.9017
# Epoch 37/500
# 5/5 [==============================] - 2s 392ms/step - loss: 0.8948
# Epoch 38/500
# 5/5 [==============================] - 2s 382ms/step - loss: 0.8882
# Epoch 39/500
# 5/5 [==============================] - 2s 385ms/step - loss: 0.8808
# Epoch 40/500
# 5/5 [==============================] - 2s 391ms/step - loss: 0.8739
# Epoch 41/500
# 5/5 [==============================] - 2s 381ms/step - loss: 0.8672
# Epoch 42/500
# 5/5 [==============================] - 2s 394ms/step - loss: 0.8598
# Epoch 43/500
# 5/5 [==============================] - 2s 384ms/step - loss: 0.8528
# Epoch 44/500
# 5/5 [==============================] - 2s 388ms/step - loss: 0.8458
# Epoch 45/500
# 5/5 [==============================] - 2s 380ms/step - loss: 0.8385
# Epoch 46/500
# 5/5 [==============================] - 2s 390ms/step - loss: 0.8316
# Epoch 47/500
# 5/5 [==============================] - 2s 383ms/step - loss: 0.8249
# Epoch 48/500
# 5/5 [==============================] - 2s 380ms/step - loss: 0.8176
# Epoch 49/500
# 5/5 [==============================] - 2s 376ms/step - loss: 0.8110
# Epoch 50/500
# 5/5 [==============================] - 2s 395ms/step - loss: 0.8042
# Epoch 51/500
# 5/5 [==============================] - 2s 385ms/step - loss: 0.7975
# Epoch 52/500
# 5/5 [==============================] - 2s 388ms/step - loss: 0.7908
# Epoch 53/500
# 5/5 [==============================] - 2s 382ms/step - loss: 0.7841
# Epoch 54/500
# 5/5 [==============================] - 2s 383ms/step - loss: 0.7778
# Epoch 55/500
# 5/5 [==============================] - 2s 378ms/step - loss: 0.7715
# Epoch 56/500
# 5/5 [==============================] - 2s 384ms/step - loss: 0.7653
# Epoch 57/500
# 5/5 [==============================] - 2s 383ms/step - loss: 0.7590
# Epoch 58/500
# 5/5 [==============================] - 2s 390ms/step - loss: 0.7535
# Epoch 59/500
# 5/5 [==============================] - 2s 386ms/step - loss: 0.7469
# Epoch 60/500
# 5/5 [==============================] - 2s 383ms/step - loss: 0.7410
# Epoch 61/500
# 5/5 [==============================] - 2s 378ms/step - loss: 0.7348
# Epoch 62/500
# 5/5 [==============================] - 2s 387ms/step - loss: 0.7286
# Epoch 63/500
# 5/5 [==============================] - 2s 387ms/step - loss: 0.7227
# Epoch 64/500
# 5/5 [==============================] - 2s 385ms/step - loss: 0.7172
# Epoch 65/500
# 5/5 [==============================] - 2s 380ms/step - loss: 0.7112
# Epoch 66/500
# 5/5 [==============================] - 2s 376ms/step - loss: 0.7053
# Epoch 67/500
# 5/5 [==============================] - 2s 383ms/step - loss: 0.6995
# Epoch 68/500
# 5/5 [==============================] - 2s 389ms/step - loss: 0.6936
# Epoch 69/500
# 5/5 [==============================] - 2s 380ms/step - loss: 0.6881
# Epoch 70/500
# 5/5 [==============================] - 2s 386ms/step - loss: 0.6820
# Epoch 71/500
# 5/5 [==============================] - 2s 396ms/step - loss: 0.6767
# Epoch 72/500
# 5/5 [==============================] - 2s 387ms/step - loss: 0.6706
# Epoch 73/500
# 5/5 [==============================] - 2s 394ms/step - loss: 0.6652
# Epoch 74/500
# 5/5 [==============================] - 2s 383ms/step - loss: 0.6597
# Epoch 75/500
# 5/5 [==============================] - 2s 389ms/step - loss: 0.6540
# Epoch 76/500
# 5/5 [==============================] - 2s 389ms/step - loss: 0.6482
# Epoch 77/500
# 5/5 [==============================] - 2s 395ms/step - loss: 0.6432
# Epoch 78/500
# 5/5 [==============================] - 2s 393ms/step - loss: 0.6379
# Epoch 79/500
# 5/5 [==============================] - 2s 385ms/step - loss: 0.6315
# Epoch 80/500
# 5/5 [==============================] - 2s 387ms/step - loss: 0.6262
# Epoch 81/500
# 5/5 [==============================] - 2s 386ms/step - loss: 0.6214
# Epoch 82/500
# 5/5 [==============================] - 2s 386ms/step - loss: 0.6160
# Epoch 83/500
# 5/5 [==============================] - 2s 388ms/step - loss: 0.6103
# Epoch 84/500
# 5/5 [==============================] - 2s 385ms/step - loss: 0.6045
# Epoch 85/500
# 5/5 [==============================] - 2s 384ms/step - loss: 0.5994
# Epoch 86/500
# 5/5 [==============================] - 2s 377ms/step - loss: 0.5938
# Epoch 87/500
# 5/5 [==============================] - 2s 384ms/step - loss: 0.5885
# Epoch 88/500
# 5/5 [==============================] - 2s 385ms/step - loss: 0.5837
# Epoch 89/500
# 5/5 [==============================] - 2s 388ms/step - loss: 0.5784
# Epoch 90/500
# 5/5 [==============================] - 2s 391ms/step - loss: 0.5727
# Epoch 91/500
# 5/5 [==============================] - 2s 382ms/step - loss: 0.5671
# Epoch 92/500
# 5/5 [==============================] - 2s 383ms/step - loss: 0.5625
# Epoch 93/500
# 5/5 [==============================] - 2s 382ms/step - loss: 0.5572
# Epoch 94/500
# 5/5 [==============================] - 2s 380ms/step - loss: 0.5523
# Epoch 95/500
# 5/5 [==============================] - 2s 388ms/step - loss: 0.5468
# Epoch 96/500
# 5/5 [==============================] - 2s 391ms/step - loss: 0.5418
# Epoch 97/500
# 5/5 [==============================] - 2s 382ms/step - loss: 0.5373
# Epoch 98/500
# 5/5 [==============================] - 2s 384ms/step - loss: 0.5314
# Epoch 99/500
# 5/5 [==============================] - 2s 385ms/step - loss: 0.5261
# Epoch 100/500
# 5/5 [==============================] - 2s 382ms/step - loss: 0.5217
# Epoch 101/500
# 5/5 [==============================] - 2s 380ms/step - loss: 0.5162
# Epoch 102/500
# 5/5 [==============================] - 2s 391ms/step - loss: 0.5108
# Epoch 103/500
# 5/5 [==============================] - 2s 383ms/step - loss: 0.5061
# Epoch 104/500
# 5/5 [==============================] - 2s 398ms/step - loss: 0.5014
# Epoch 105/500
# 5/5 [==============================] - 2s 385ms/step - loss: 0.4964
# Epoch 106/500
# 5/5 [==============================] - 2s 385ms/step - loss: 0.4919
# Epoch 107/500
# 5/5 [==============================] - 2s 396ms/step - loss: 0.4866
# Epoch 108/500
# 5/5 [==============================] - 2s 376ms/step - loss: 0.4818
# Epoch 109/500
# 5/5 [==============================] - 2s 387ms/step - loss: 0.4770
# Epoch 110/500
# 5/5 [==============================] - 2s 384ms/step - loss: 0.4717
# Epoch 111/500
# 5/5 [==============================] - 2s 386ms/step - loss: 0.4667
# Epoch 112/500
# 5/5 [==============================] - 2s 389ms/step - loss: 0.4618
# Epoch 113/500
# 5/5 [==============================] - 2s 373ms/step - loss: 0.4573
# Epoch 114/500
# 5/5 [==============================] - 2s 383ms/step - loss: 0.4529
# Epoch 115/500
# 5/5 [==============================] - 2s 384ms/step - loss: 0.4480
# Epoch 116/500
# 5/5 [==============================] - 2s 378ms/step - loss: 0.4431
# Epoch 117/500
# 5/5 [==============================] - 2s 391ms/step - loss: 0.4384
# Epoch 118/500
# 5/5 [==============================] - 2s 388ms/step - loss: 0.4339
# Epoch 119/500
# 5/5 [==============================] - 2s 385ms/step - loss: 0.4292
# Epoch 120/500
# 5/5 [==============================] - 2s 379ms/step - loss: 0.4242
# Epoch 121/500
# 5/5 [==============================] - 2s 378ms/step - loss: 0.4197
# Epoch 122/500
# 5/5 [==============================] - 2s 377ms/step - loss: 0.4155
# Epoch 123/500
# 5/5 [==============================] - 2s 377ms/step - loss: 0.4106
# Epoch 124/500
# 5/5 [==============================] - 2s 389ms/step - loss: 0.4069
# Epoch 125/500
# 5/5 [==============================] - 2s 381ms/step - loss: 0.4017
# Epoch 126/500
# 5/5 [==============================] - 2s 387ms/step - loss: 0.3974
# Epoch 127/500
# 5/5 [==============================] - 2s 388ms/step - loss: 0.3945
# Epoch 128/500
# 5/5 [==============================] - 2s 380ms/step - loss: 0.3893
# Epoch 129/500
# 5/5 [==============================] - 2s 386ms/step - loss: 0.3861
# Epoch 130/500
# 5/5 [==============================] - 2s 374ms/step - loss: 0.3805
# Epoch 131/500
# 5/5 [==============================] - 2s 379ms/step - loss: 0.3771
# Epoch 132/500
# 5/5 [==============================] - 2s 392ms/step - loss: 0.3730
# Epoch 133/500
# 5/5 [==============================] - 2s 381ms/step - loss: 0.3685
# Epoch 134/500
# 5/5 [==============================] - 2s 380ms/step - loss: 0.3646
# Epoch 135/500
# 5/5 [==============================] - 2s 377ms/step - loss: 0.3602
# Epoch 136/500
# 5/5 [==============================] - 2s 390ms/step - loss: 0.3562
# Epoch 137/500
# 5/5 [==============================] - 2s 387ms/step - loss: 0.3528
# Epoch 138/500
# 5/5 [==============================] - 2s 379ms/step - loss: 0.3483
# Epoch 139/500
# 5/5 [==============================] - 2s 386ms/step - loss: 0.3445
# Epoch 140/500
# 5/5 [==============================] - 2s 388ms/step - loss: 0.3410
# Epoch 141/500
# 5/5 [==============================] - 2s 376ms/step - loss: 0.3367
# Epoch 142/500
# 5/5 [==============================] - 2s 388ms/step - loss: 0.3337
# Epoch 143/500
# 5/5 [==============================] - 2s 379ms/step - loss: 0.3302
# Epoch 144/500
# 5/5 [==============================] - 2s 388ms/step - loss: 0.3266
# Epoch 145/500
# 5/5 [==============================] - 2s 378ms/step - loss: 0.3222
# Epoch 146/500
# 5/5 [==============================] - 2s 386ms/step - loss: 0.3190
# Epoch 147/500
# 5/5 [==============================] - 2s 386ms/step - loss: 0.3160
# Epoch 148/500
# 5/5 [==============================] - 2s 381ms/step - loss: 0.3126
# Epoch 149/500
# 5/5 [==============================] - 2s 378ms/step - loss: 0.3091
# Epoch 150/500
# 5/5 [==============================] - 2s 380ms/step - loss: 0.3053
# Epoch 151/500
# 5/5 [==============================] - 2s 376ms/step - loss: 0.3025
# Epoch 152/500
# 5/5 [==============================] - 2s 383ms/step - loss: 0.2984
# Epoch 153/500
# 5/5 [==============================] - 2s 379ms/step - loss: 0.2954
# Epoch 154/500
# 5/5 [==============================] - 2s 378ms/step - loss: 0.2925
# Epoch 155/500
# 5/5 [==============================] - 2s 371ms/step - loss: 0.2887
# Epoch 156/500
# 5/5 [==============================] - 2s 371ms/step - loss: 0.2863
# Epoch 157/500
# 5/5 [==============================] - 2s 379ms/step - loss: 0.2831
# Epoch 158/500
# 5/5 [==============================] - 2s 377ms/step - loss: 0.2793
# Epoch 159/500
# 5/5 [==============================] - 2s 383ms/step - loss: 0.2763
# Epoch 160/500
# 5/5 [==============================] - 2s 381ms/step - loss: 0.2737
# Epoch 161/500
# 5/5 [==============================] - 2s 377ms/step - loss: 0.2703
# Epoch 162/500
# 5/5 [==============================] - 2s 393ms/step - loss: 0.2673
# Epoch 163/500
# 5/5 [==============================] - 2s 384ms/step - loss: 0.2646
# Epoch 164/500
# 5/5 [==============================] - 2s 380ms/step - loss: 0.2624
# Epoch 165/500
# 5/5 [==============================] - 2s 373ms/step - loss: 0.2591
# Epoch 166/500
# 5/5 [==============================] - 2s 380ms/step - loss: 0.2555
# Epoch 167/500
# 5/5 [==============================] - 2s 382ms/step - loss: 0.2534
# Epoch 168/500
# 5/5 [==============================] - 2s 381ms/step - loss: 0.2503
# Epoch 169/500
# 5/5 [==============================] - 2s 381ms/step - loss: 0.2483
# Epoch 170/500
# 5/5 [==============================] - 2s 376ms/step - loss: 0.2457
# Epoch 171/500
# 5/5 [==============================] - 2s 382ms/step - loss: 0.2431
# Epoch 172/500
# 5/5 [==============================] - 2s 384ms/step - loss: 0.2403
# Epoch 173/500
# 5/5 [==============================] - 2s 379ms/step - loss: 0.2378
# Epoch 174/500
# 5/5 [==============================] - 2s 388ms/step - loss: 0.2351
# Epoch 175/500
# 5/5 [==============================] - 2s 374ms/step - loss: 0.2341
# Epoch 176/500
# 5/5 [==============================] - 2s 385ms/step - loss: 0.2308
# Epoch 177/500
# 5/5 [==============================] - 2s 377ms/step - loss: 0.2278
# Epoch 178/500
# 5/5 [==============================] - 2s 380ms/step - loss: 0.2256
# Epoch 179/500
# 5/5 [==============================] - 2s 381ms/step - loss: 0.2231
# Epoch 180/500
# 5/5 [==============================] - 2s 371ms/step - loss: 0.2201
# Epoch 181/500
# 5/5 [==============================] - 2s 386ms/step - loss: 0.2178
# Epoch 182/500
# 5/5 [==============================] - 2s 385ms/step - loss: 0.2165
# Epoch 183/500
# 5/5 [==============================] - 2s 384ms/step - loss: 0.2136
# Epoch 184/500
# 5/5 [==============================] - 2s 388ms/step - loss: 0.2109
# Epoch 185/500
# 5/5 [==============================] - 2s 371ms/step - loss: 0.2093
# Epoch 186/500
# 5/5 [==============================] - 2s 384ms/step - loss: 0.2072
# Epoch 187/500
# 5/5 [==============================] - 2s 386ms/step - loss: 0.2052
# Epoch 188/500
# 5/5 [==============================] - 2s 387ms/step - loss: 0.2034
# Epoch 189/500
# 5/5 [==============================] - 2s 380ms/step - loss: 0.2008
# Epoch 190/500
# 5/5 [==============================] - 2s 380ms/step - loss: 0.1988
# Epoch 191/500
# 5/5 [==============================] - 2s 384ms/step - loss: 0.1971
# Epoch 192/500
# 5/5 [==============================] - 2s 386ms/step - loss: 0.1950
# Epoch 193/500
# 5/5 [==============================] - 2s 379ms/step - loss: 0.1929
# Epoch 194/500
# 5/5 [==============================] - 2s 375ms/step - loss: 0.1913
# Epoch 195/500
# 5/5 [==============================] - 2s 370ms/step - loss: 0.1896
# Epoch 196/500
# 5/5 [==============================] - 2s 380ms/step - loss: 0.1868
# Epoch 197/500
# 5/5 [==============================] - 2s 384ms/step - loss: 0.1858
# Epoch 198/500
# 5/5 [==============================] - 2s 378ms/step - loss: 0.1832
# Epoch 199/500
# 5/5 [==============================] - 2s 378ms/step - loss: 0.1820
# Epoch 200/500
# 5/5 [==============================] - 2s 387ms/step - loss: 0.1792
# Epoch 201/500
# 5/5 [==============================] - 2s 380ms/step - loss: 0.1780
# Epoch 202/500
# 5/5 [==============================] - 2s 394ms/step - loss: 0.1765
# Epoch 203/500
# 5/5 [==============================] - 2s 381ms/step - loss: 0.1744
# Epoch 204/500
# 5/5 [==============================] - 2s 389ms/step - loss: 0.1718
# Epoch 205/500
# 5/5 [==============================] - 2s 392ms/step - loss: 0.1712
# Epoch 206/500
# 5/5 [==============================] - 2s 384ms/step - loss: 0.1687
# Epoch 207/500
# 5/5 [==============================] - 2s 382ms/step - loss: 0.1674
# Epoch 208/500
# 5/5 [==============================] - 2s 390ms/step - loss: 0.1670
# Epoch 209/500
# 5/5 [==============================] - 2s 390ms/step - loss: 0.1641
# Epoch 210/500
# 5/5 [==============================] - 2s 385ms/step - loss: 0.1630
# Epoch 211/500
# 5/5 [==============================] - 2s 393ms/step - loss: 0.1609
# Epoch 212/500
# 5/5 [==============================] - 2s 393ms/step - loss: 0.1587
# Epoch 213/500
# 5/5 [==============================] - 2s 380ms/step - loss: 0.1574
# Epoch 214/500
# 5/5 [==============================] - 2s 370ms/step - loss: 0.1563
# Epoch 215/500
# 5/5 [==============================] - 2s 378ms/step - loss: 0.1549
# Epoch 216/500
# 5/5 [==============================] - 2s 375ms/step - loss: 0.1537
# Epoch 217/500
# 5/5 [==============================] - 2s 378ms/step - loss: 0.1521
# Epoch 218/500
# 5/5 [==============================] - 2s 386ms/step - loss: 0.1498
# Epoch 219/500
# 5/5 [==============================] - 2s 379ms/step - loss: 0.1494
# Epoch 220/500
# 5/5 [==============================] - 2s 381ms/step - loss: 0.1482
# Epoch 221/500
# 5/5 [==============================] - 2s 379ms/step - loss: 0.1466
# Epoch 222/500
# 5/5 [==============================] - 2s 382ms/step - loss: 0.1444
# Epoch 223/500
# 5/5 [==============================] - 2s 378ms/step - loss: 0.1429
# Epoch 224/500
# 5/5 [==============================] - 2s 390ms/step - loss: 0.1414
# Epoch 225/500
# 5/5 [==============================] - 2s 381ms/step - loss: 0.1397
# Epoch 226/500
# 5/5 [==============================] - 2s 379ms/step - loss: 0.1395
# Epoch 227/500
# 5/5 [==============================] - 2s 373ms/step - loss: 0.1384
# Epoch 228/500
# 5/5 [==============================] - 2s 384ms/step - loss: 0.1372
# Epoch 229/500
# 5/5 [==============================] - 2s 382ms/step - loss: 0.1356
# Epoch 230/500
# 5/5 [==============================] - 2s 384ms/step - loss: 0.1344
# Epoch 231/500
# 5/5 [==============================] - 2s 385ms/step - loss: 0.1327
# Epoch 232/500
# 5/5 [==============================] - 2s 392ms/step - loss: 0.1314
# Epoch 233/500
# 5/5 [==============================] - 2s 391ms/step - loss: 0.1306
# Epoch 234/500
# 5/5 [==============================] - 2s 380ms/step - loss: 0.1292
# Epoch 235/500
# 5/5 [==============================] - 2s 384ms/step - loss: 0.1268
# Epoch 236/500
# 5/5 [==============================] - 2s 380ms/step - loss: 0.1269
# Epoch 237/500
# 5/5 [==============================] - 2s 390ms/step - loss: 0.1252
# Epoch 238/500
# 5/5 [==============================] - 2s 371ms/step - loss: 0.1247
# Epoch 239/500
# 5/5 [==============================] - 2s 382ms/step - loss: 0.1231
# Epoch 240/500
# 5/5 [==============================] - 2s 377ms/step - loss: 0.1227
# Epoch 241/500
# 5/5 [==============================] - 2s 385ms/step - loss: 0.1207
# Epoch 242/500
# 5/5 [==============================] - 2s 379ms/step - loss: 0.1198
# Epoch 243/500
# 5/5 [==============================] - 2s 379ms/step - loss: 0.1190
# Epoch 244/500
# 5/5 [==============================] - 2s 377ms/step - loss: 0.1185
# Epoch 245/500
# 5/5 [==============================] - 2s 369ms/step - loss: 0.1167
# Epoch 246/500
# 5/5 [==============================] - 2s 389ms/step - loss: 0.1155
# Epoch 247/500
# 5/5 [==============================] - 2s 384ms/step - loss: 0.1141
# Epoch 248/500
# 5/5 [==============================] - 2s 390ms/step - loss: 0.1134
# Epoch 249/500
# 5/5 [==============================] - 2s 374ms/step - loss: 0.1124
# Epoch 250/500
# 5/5 [==============================] - 2s 383ms/step - loss: 0.1115
# Epoch 251/500
# 5/5 [==============================] - 2s 380ms/step - loss: 0.1103
# Epoch 252/500
# 5/5 [==============================] - 2s 375ms/step - loss: 0.1092
# Epoch 253/500
# 5/5 [==============================] - 2s 380ms/step - loss: 0.1092
# Epoch 254/500
# 5/5 [==============================] - 2s 376ms/step - loss: 0.1077
# Epoch 255/500
# 5/5 [==============================] - 2s 381ms/step - loss: 0.1064
# Epoch 256/500
# 5/5 [==============================] - 2s 376ms/step - loss: 0.1055
# Epoch 257/500
# 5/5 [==============================] - 2s 373ms/step - loss: 0.1041
# Epoch 258/500
# 5/5 [==============================] - 2s 381ms/step - loss: 0.1038
# Epoch 259/500
# 5/5 [==============================] - 2s 380ms/step - loss: 0.1026
# Epoch 260/500
# 5/5 [==============================] - 2s 375ms/step - loss: 0.1022
# Epoch 261/500
# 5/5 [==============================] - 2s 384ms/step - loss: 0.1009
# Epoch 262/500
# 5/5 [==============================] - 2s 380ms/step - loss: 0.1002
# Epoch 263/500
# 5/5 [==============================] - 2s 374ms/step - loss: 0.0994
# Epoch 264/500
# 5/5 [==============================] - 2s 374ms/step - loss: 0.0979
# Epoch 265/500
# 5/5 [==============================] - 2s 385ms/step - loss: 0.0973
# Epoch 266/500
# 5/5 [==============================] - 2s 385ms/step - loss: 0.0967
# Epoch 267/500
# 5/5 [==============================] - 2s 377ms/step - loss: 0.0950
# Epoch 268/500
# 5/5 [==============================] - 2s 386ms/step - loss: 0.0950
# Epoch 269/500
# 5/5 [==============================] - 2s 386ms/step - loss: 0.0937
# Epoch 270/500
# 5/5 [==============================] - 2s 380ms/step - loss: 0.0928
# Epoch 271/500
# 5/5 [==============================] - 2s 375ms/step - loss: 0.0918
# Epoch 272/500
# 5/5 [==============================] - 2s 383ms/step - loss: 0.0920
# Epoch 273/500
# 5/5 [==============================] - 2s 373ms/step - loss: 0.0916
# Epoch 274/500
# 5/5 [==============================] - 2s 391ms/step - loss: 0.0902
# Epoch 275/500
# 5/5 [==============================] - 2s 377ms/step - loss: 0.0894
# Epoch 276/500
# 5/5 [==============================] - 2s 385ms/step - loss: 0.0891
# Epoch 277/500
# 5/5 [==============================] - 2s 377ms/step - loss: 0.0874
# Epoch 278/500
# 5/5 [==============================] - 2s 371ms/step - loss: 0.0867
# Epoch 279/500
# 5/5 [==============================] - 2s 375ms/step - loss: 0.0863
# Epoch 280/500
# 5/5 [==============================] - 2s 380ms/step - loss: 0.0858
# Epoch 281/500
# 5/5 [==============================] - 2s 384ms/step - loss: 0.0849
# Epoch 282/500
# 5/5 [==============================] - 2s 383ms/step - loss: 0.0842
# Epoch 283/500
# 5/5 [==============================] - 2s 375ms/step - loss: 0.0838
# Epoch 284/500
# 5/5 [==============================] - 2s 382ms/step - loss: 0.0830
# Epoch 285/500
# 5/5 [==============================] - 2s 372ms/step - loss: 0.0823
# Epoch 286/500
# 5/5 [==============================] - 2s 385ms/step - loss: 0.0822
# Epoch 287/500
# 5/5 [==============================] - 2s 384ms/step - loss: 0.0807
# Epoch 288/500
# 5/5 [==============================] - 2s 378ms/step - loss: 0.0801
# Epoch 289/500
# 5/5 [==============================] - 2s 385ms/step - loss: 0.0797
# Epoch 290/500
# 5/5 [==============================] - 2s 373ms/step - loss: 0.0783
# Epoch 291/500
# 5/5 [==============================] - 2s 378ms/step - loss: 0.0781
# Epoch 292/500
# 5/5 [==============================] - 2s 386ms/step - loss: 0.0777
# Epoch 293/500
# 5/5 [==============================] - 2s 377ms/step - loss: 0.0774
# Epoch 294/500
# 5/5 [==============================] - 2s 375ms/step - loss: 0.0762
# Epoch 295/500
# 5/5 [==============================] - 2s 378ms/step - loss: 0.0761
# Epoch 296/500
# 5/5 [==============================] - 2s 376ms/step - loss: 0.0754
# Epoch 297/500
# 5/5 [==============================] - 2s 373ms/step - loss: 0.0744
# Epoch 298/500
# 5/5 [==============================] - 2s 381ms/step - loss: 0.0741
# Epoch 299/500
# 5/5 [==============================] - 2s 381ms/step - loss: 0.0732
# Epoch 300/500
# 5/5 [==============================] - 2s 379ms/step - loss: 0.0726
# Epoch 301/500
# 5/5 [==============================] - 2s 379ms/step - loss: 0.0724
# Epoch 302/500
# 5/5 [==============================] - 2s 374ms/step - loss: 0.0719
# Epoch 303/500
# 5/5 [==============================] - 2s 378ms/step - loss: 0.0703
# Epoch 304/500
# 5/5 [==============================] - 2s 384ms/step - loss: 0.0707
# Epoch 305/500
# 5/5 [==============================] - 2s 381ms/step - loss: 0.0705
# Epoch 306/500
# 5/5 [==============================] - 2s 375ms/step - loss: 0.0689
# Epoch 307/500
# 5/5 [==============================] - 2s 384ms/step - loss: 0.0691
# Epoch 308/500
# 5/5 [==============================] - 2s 378ms/step - loss: 0.0693
# Epoch 309/500
# 5/5 [==============================] - 2s 385ms/step - loss: 0.0684
# Epoch 310/500
# 5/5 [==============================] - 2s 380ms/step - loss: 0.0674
# Epoch 311/500
# 5/5 [==============================] - 2s 379ms/step - loss: 0.0670
# Epoch 312/500
# 5/5 [==============================] - 2s 380ms/step - loss: 0.0660
# Epoch 313/500
# 5/5 [==============================] - 2s 383ms/step - loss: 0.0664
# Epoch 314/500
# 5/5 [==============================] - 2s 374ms/step - loss: 0.0662
# Epoch 315/500
# 5/5 [==============================] - 2s 377ms/step - loss: 0.0645
# Epoch 316/500
# 5/5 [==============================] - 2s 381ms/step - loss: 0.0646
# Epoch 317/500
# 5/5 [==============================] - 2s 380ms/step - loss: 0.0638
# Epoch 318/500
# 5/5 [==============================] - 2s 383ms/step - loss: 0.0634
# Epoch 319/500
# 5/5 [==============================] - 2s 393ms/step - loss: 0.0625
# Epoch 320/500
# 5/5 [==============================] - 2s 382ms/step - loss: 0.0630
# Epoch 321/500
# 5/5 [==============================] - 2s 384ms/step - loss: 0.0617
# Epoch 322/500
# 5/5 [==============================] - 2s 370ms/step - loss: 0.0613
# Epoch 323/500
# 5/5 [==============================] - 2s 388ms/step - loss: 0.0607
# Epoch 324/500
# 5/5 [==============================] - 2s 387ms/step - loss: 0.0605
# Epoch 325/500
# 5/5 [==============================] - 2s 383ms/step - loss: 0.0600
# Epoch 326/500
# 5/5 [==============================] - 2s 392ms/step - loss: 0.0592
# Epoch 327/500
# 5/5 [==============================] - 2s 382ms/step - loss: 0.0596
# Epoch 328/500
# 5/5 [==============================] - 2s 378ms/step - loss: 0.0587
# Epoch 329/500
# 5/5 [==============================] - 2s 379ms/step - loss: 0.0586
# Epoch 330/500
# 5/5 [==============================] - 2s 372ms/step - loss: 0.0585
# Epoch 331/500
# 5/5 [==============================] - 2s 379ms/step - loss: 0.0576
# Epoch 332/500
# 5/5 [==============================] - 2s 377ms/step - loss: 0.0579
# Epoch 333/500
# 5/5 [==============================] - 2s 375ms/step - loss: 0.0574
# Epoch 334/500
# 5/5 [==============================] - 2s 390ms/step - loss: 0.0558
# Epoch 335/500
# 5/5 [==============================] - 2s 388ms/step - loss: 0.0562
# Epoch 336/500
# 5/5 [==============================] - 2s 380ms/step - loss: 0.0554
# Epoch 337/500
# 5/5 [==============================] - 2s 386ms/step - loss: 0.0554
# Epoch 338/500
# 5/5 [==============================] - 2s 380ms/step - loss: 0.0548
# Epoch 339/500
# 5/5 [==============================] - 2s 382ms/step - loss: 0.0544
# Epoch 340/500
# 5/5 [==============================] - 2s 380ms/step - loss: 0.0538
# Epoch 341/500
# 5/5 [==============================] - 2s 371ms/step - loss: 0.0535
# Epoch 342/500
# 5/5 [==============================] - 2s 377ms/step - loss: 0.0539
# Epoch 343/500
# 5/5 [==============================] - 2s 375ms/step - loss: 0.0531
# Epoch 344/500
# 5/5 [==============================] - 2s 376ms/step - loss: 0.0525
# Epoch 345/500
# 5/5 [==============================] - 2s 374ms/step - loss: 0.0521
# Epoch 346/500
# 5/5 [==============================] - 2s 388ms/step - loss: 0.0519
# Epoch 347/500
# 5/5 [==============================] - 2s 382ms/step - loss: 0.0517
# Epoch 348/500
# 5/5 [==============================] - 2s 380ms/step - loss: 0.0508
# Epoch 349/500
# 5/5 [==============================] - 2s 386ms/step - loss: 0.0509
# Epoch 350/500
# 5/5 [==============================] - 2s 377ms/step - loss: 0.0505
# Epoch 351/500
# 5/5 [==============================] - 2s 386ms/step - loss: 0.0498
# Epoch 352/500
# 5/5 [==============================] - 2s 381ms/step - loss: 0.0498
# Epoch 353/500
# 5/5 [==============================] - 2s 381ms/step - loss: 0.0492
# Epoch 354/500
# 5/5 [==============================] - 2s 369ms/step - loss: 0.0496
# Epoch 355/500
# 5/5 [==============================] - 2s 384ms/step - loss: 0.0486
# Epoch 356/500
# 5/5 [==============================] - 2s 383ms/step - loss: 0.0485
# Epoch 357/500
# 5/5 [==============================] - 2s 374ms/step - loss: 0.0487
# Epoch 358/500
# 5/5 [==============================] - 2s 386ms/step - loss: 0.0482
# Epoch 359/500
# 5/5 [==============================] - 2s 379ms/step - loss: 0.0476
# Epoch 360/500
# 5/5 [==============================] - 2s 390ms/step - loss: 0.0470
# Epoch 361/500
# 5/5 [==============================] - 2s 382ms/step - loss: 0.0477
# Epoch 362/500
# 5/5 [==============================] - 2s 382ms/step - loss: 0.0469
# Epoch 363/500
# 5/5 [==============================] - 2s 380ms/step - loss: 0.0468
# Epoch 364/500
# 5/5 [==============================] - 2s 374ms/step - loss: 0.0459
# Epoch 365/500
# 5/5 [==============================] - 2s 376ms/step - loss: 0.0456
# Epoch 366/500
# 5/5 [==============================] - 2s 386ms/step - loss: 0.0458
# Epoch 367/500
# 5/5 [==============================] - 2s 379ms/step - loss: 0.0455
# Epoch 368/500
# 5/5 [==============================] - 2s 379ms/step - loss: 0.0458
# Epoch 369/500
# 5/5 [==============================] - 2s 390ms/step - loss: 0.0448
# Epoch 370/500
# 5/5 [==============================] - 2s 382ms/step - loss: 0.0443
# Epoch 371/500
# 5/5 [==============================] - 2s 388ms/step - loss: 0.0444
# Epoch 372/500
# 5/5 [==============================] - 2s 378ms/step - loss: 0.0439
# Epoch 373/500
# 5/5 [==============================] - 2s 375ms/step - loss: 0.0436
# Epoch 374/500
# 5/5 [==============================] - 2s 375ms/step - loss: 0.0434
# Epoch 375/500
# 5/5 [==============================] - 2s 375ms/step - loss: 0.0434
# Epoch 376/500
# 5/5 [==============================] - 2s 374ms/step - loss: 0.0426
# Epoch 377/500
# 5/5 [==============================] - 2s 389ms/step - loss: 0.0434
# Epoch 378/500
# 5/5 [==============================] - 2s 383ms/step - loss: 0.0428
# Epoch 379/500
# 5/5 [==============================] - 2s 379ms/step - loss: 0.0421
# Epoch 380/500
# 5/5 [==============================] - 2s 385ms/step - loss: 0.0419
# Epoch 381/500
# 5/5 [==============================] - 2s 378ms/step - loss: 0.0422
# Epoch 382/500
# 5/5 [==============================] - 2s 381ms/step - loss: 0.0409
# Epoch 383/500
# 5/5 [==============================] - 2s 372ms/step - loss: 0.0410
# Epoch 384/500
# 5/5 [==============================] - 2s 382ms/step - loss: 0.0411
# Epoch 385/500
# 5/5 [==============================] - 2s 380ms/step - loss: 0.0411
# Epoch 386/500
# 5/5 [==============================] - 2s 377ms/step - loss: 0.0404
# Epoch 387/500
# 5/5 [==============================] - 2s 383ms/step - loss: 0.0404
# Epoch 388/500
# 5/5 [==============================] - 2s 383ms/step - loss: 0.0401
# Epoch 389/500
# 5/5 [==============================] - 2s 385ms/step - loss: 0.0404
# Epoch 390/500
# 5/5 [==============================] - 2s 389ms/step - loss: 0.0395
# Epoch 391/500
# 5/5 [==============================] - 2s 381ms/step - loss: 0.0390
# Epoch 392/500
# 5/5 [==============================] - 2s 386ms/step - loss: 0.0392
# Epoch 393/500
# 5/5 [==============================] - 2s 375ms/step - loss: 0.0388
# Epoch 394/500
# 5/5 [==============================] - 2s 369ms/step - loss: 0.0388
# Epoch 395/500
# 5/5 [==============================] - 2s 375ms/step - loss: 0.0381
# Epoch 396/500
# 5/5 [==============================] - 2s 381ms/step - loss: 0.0384
# Epoch 397/500
# 5/5 [==============================] - 2s 381ms/step - loss: 0.0380
# Epoch 398/500
# 5/5 [==============================] - 2s 375ms/step - loss: 0.0376
# Epoch 399/500
# 5/5 [==============================] - 2s 380ms/step - loss: 0.0379
# Epoch 400/500
# 5/5 [==============================] - 2s 385ms/step - loss: 0.0375
# Epoch 401/500
# 5/5 [==============================] - 2s 380ms/step - loss: 0.0376
# Epoch 402/500
# 5/5 [==============================] - 2s 375ms/step - loss: 0.0371
# Epoch 403/500
# 5/5 [==============================] - 2s 378ms/step - loss: 0.0365
# Epoch 404/500
# 5/5 [==============================] - 2s 382ms/step - loss: 0.0368
# Epoch 405/500
# 5/5 [==============================] - 2s 384ms/step - loss: 0.0368
# Epoch 406/500
# 5/5 [==============================] - 2s 376ms/step - loss: 0.0361
# Epoch 407/500
# 5/5 [==============================] - 2s 383ms/step - loss: 0.0367
# Epoch 408/500
# 5/5 [==============================] - 2s 388ms/step - loss: 0.0358
# Epoch 409/500
# 5/5 [==============================] - 2s 378ms/step - loss: 0.0358
# Epoch 410/500
# 5/5 [==============================] - 2s 389ms/step - loss: 0.0351
# Epoch 411/500
# 5/5 [==============================] - 2s 392ms/step - loss: 0.0354
# Epoch 412/500
# 5/5 [==============================] - 2s 377ms/step - loss: 0.0352
# Epoch 413/500
# 5/5 [==============================] - 2s 376ms/step - loss: 0.0346
# Epoch 414/500
# 5/5 [==============================] - 2s 376ms/step - loss: 0.0347
# Epoch 415/500
# 5/5 [==============================] - 2s 384ms/step - loss: 0.0345
# Epoch 416/500
# 5/5 [==============================] - 2s 396ms/step - loss: 0.0345
# Epoch 417/500
# 5/5 [==============================] - 2s 376ms/step - loss: 0.0344
# Epoch 418/500
# 5/5 [==============================] - 2s 388ms/step - loss: 0.0341
# Epoch 419/500
# 5/5 [==============================] - 2s 378ms/step - loss: 0.0340
# Epoch 420/500
# 5/5 [==============================] - 2s 376ms/step - loss: 0.0334
# Epoch 421/500
# 5/5 [==============================] - 2s 382ms/step - loss: 0.0336
# Epoch 422/500
# 5/5 [==============================] - 2s 383ms/step - loss: 0.0335
# Epoch 423/500
# 5/5 [==============================] - 2s 386ms/step - loss: 0.0332
# Epoch 424/500
# 5/5 [==============================] - 2s 388ms/step - loss: 0.0327
# Epoch 425/500
# 5/5 [==============================] - 2s 384ms/step - loss: 0.0330
# Epoch 426/500
# 5/5 [==============================] - 2s 386ms/step - loss: 0.0333
# Epoch 427/500
# 5/5 [==============================] - 2s 384ms/step - loss: 0.0327
# Epoch 428/500
# 5/5 [==============================] - 2s 384ms/step - loss: 0.0329
# Epoch 429/500
# 5/5 [==============================] - 2s 381ms/step - loss: 0.0329
# Epoch 430/500
# 5/5 [==============================] - 2s 376ms/step - loss: 0.0328
# Epoch 431/500
# 5/5 [==============================] - 2s 375ms/step - loss: 0.0316
# Epoch 432/500
# 5/5 [==============================] - 2s 375ms/step - loss: 0.0319
# Epoch 433/500
# 5/5 [==============================] - 2s 377ms/step - loss: 0.0316
# Epoch 434/500
# 5/5 [==============================] - 2s 383ms/step - loss: 0.0313
# Epoch 435/500
# 5/5 [==============================] - 2s 373ms/step - loss: 0.0314
# Epoch 436/500
# 5/5 [==============================] - 2s 388ms/step - loss: 0.0312
# Epoch 437/500
# 5/5 [==============================] - 2s 382ms/step - loss: 0.0309
# Epoch 438/500
# 5/5 [==============================] - 2s 379ms/step - loss: 0.0307
# Epoch 439/500
# 5/5 [==============================] - 2s 379ms/step - loss: 0.0310
# Epoch 440/500
# 5/5 [==============================] - 2s 386ms/step - loss: 0.0307
# Epoch 441/500
# 5/5 [==============================] - 2s 381ms/step - loss: 0.0307
# Epoch 442/500
# 5/5 [==============================] - 2s 392ms/step - loss: 0.0308
# Epoch 443/500
# 5/5 [==============================] - 2s 385ms/step - loss: 0.0300
# Epoch 444/500
# 5/5 [==============================] - 2s 377ms/step - loss: 0.0304
# Epoch 445/500
# 5/5 [==============================] - 2s 374ms/step - loss: 0.0300
# Epoch 446/500
# 5/5 [==============================] - 2s 377ms/step - loss: 0.0300
# Epoch 447/500
# 5/5 [==============================] - 2s 380ms/step - loss: 0.0301
# Epoch 448/500
# 5/5 [==============================] - 2s 389ms/step - loss: 0.0293
# Epoch 449/500
# 5/5 [==============================] - 2s 386ms/step - loss: 0.0298
# Epoch 450/500
# 5/5 [==============================] - 2s 379ms/step - loss: 0.0290
# Epoch 451/500
# 5/5 [==============================] - 2s 389ms/step - loss: 0.0290
# Epoch 452/500
# 5/5 [==============================] - 2s 384ms/step - loss: 0.0293
# Epoch 453/500
# 5/5 [==============================] - 2s 373ms/step - loss: 0.0290
# Epoch 454/500
# 5/5 [==============================] - 2s 382ms/step - loss: 0.0286
# Epoch 455/500
# 5/5 [==============================] - 2s 385ms/step - loss: 0.0287
# Epoch 456/500
# 5/5 [==============================] - 2s 375ms/step - loss: 0.0286
# Epoch 457/500
# 5/5 [==============================] - 2s 379ms/step - loss: 0.0284
# Epoch 458/500
# 5/5 [==============================] - 2s 376ms/step - loss: 0.0278
# Epoch 459/500
# 5/5 [==============================] - 2s 392ms/step - loss: 0.0286
# Epoch 460/500
# 5/5 [==============================] - 2s 389ms/step - loss: 0.0279
# Epoch 461/500
# 5/5 [==============================] - 2s 382ms/step - loss: 0.0278
# Epoch 462/500
# 5/5 [==============================] - 2s 387ms/step - loss: 0.0281
# Epoch 463/500
# 5/5 [==============================] - 2s 390ms/step - loss: 0.0277
# Epoch 464/500
# 5/5 [==============================] - 2s 384ms/step - loss: 0.0274
# Epoch 465/500
# 5/5 [==============================] - 2s 384ms/step - loss: 0.0278
# Epoch 466/500
# 5/5 [==============================] - 2s 386ms/step - loss: 0.0278
# Epoch 467/500
# 5/5 [==============================] - 2s 387ms/step - loss: 0.0274
# Epoch 468/500
# 5/5 [==============================] - 2s 379ms/step - loss: 0.0274
# Epoch 469/500
# 5/5 [==============================] - 2s 383ms/step - loss: 0.0273
# Epoch 470/500
# 5/5 [==============================] - 2s 381ms/step - loss: 0.0271
# Epoch 471/500
# 5/5 [==============================] - 2s 387ms/step - loss: 0.0274
# Epoch 472/500
# 5/5 [==============================] - 2s 387ms/step - loss: 0.0269
# Epoch 473/500
# 5/5 [==============================] - 2s 378ms/step - loss: 0.0265
# Epoch 474/500
# 5/5 [==============================] - 2s 379ms/step - loss: 0.0263
# Epoch 475/500
# 5/5 [==============================] - 2s 373ms/step - loss: 0.0269
# Epoch 476/500
# 5/5 [==============================] - 2s 378ms/step - loss: 0.0265
# Epoch 477/500
# 5/5 [==============================] - 2s 380ms/step - loss: 0.0264
# Epoch 478/500
# 5/5 [==============================] - 2s 386ms/step - loss: 0.0262
# Epoch 479/500
# 5/5 [==============================] - 2s 373ms/step - loss: 0.0256
# Epoch 480/500
# 5/5 [==============================] - 2s 386ms/step - loss: 0.0258
# Epoch 481/500
# 5/5 [==============================] - 2s 375ms/step - loss: 0.0257
# Epoch 482/500
# 5/5 [==============================] - 2s 379ms/step - loss: 0.0256
# Epoch 483/500
# 5/5 [==============================] - 2s 375ms/step - loss: 0.0255
# Epoch 484/500
# 5/5 [==============================] - 2s 376ms/step - loss: 0.0250
# Epoch 485/500
# 5/5 [==============================] - 2s 382ms/step - loss: 0.0255
# Epoch 486/500
# 5/5 [==============================] - 2s 391ms/step - loss: 0.0250
# Epoch 487/500
# 5/5 [==============================] - 2s 389ms/step - loss: 0.0253
# Epoch 488/500
# 5/5 [==============================] - 2s 381ms/step - loss: 0.0251
# Epoch 489/500
# 5/5 [==============================] - 2s 395ms/step - loss: 0.0250
# Epoch 490/500
# 5/5 [==============================] - 2s 375ms/step - loss: 0.0250
# Epoch 491/500
# 5/5 [==============================] - 2s 374ms/step - loss: 0.0250
# Epoch 492/500
# 5/5 [==============================] - 2s 378ms/step - loss: 0.0245
# Epoch 493/500
# 5/5 [==============================] - 2s 382ms/step - loss: 0.0243
# Epoch 494/500
# 5/5 [==============================] - 2s 379ms/step - loss: 0.0247
# Epoch 495/500
# 5/5 [==============================] - 2s 381ms/step - loss: 0.0248
# Epoch 496/500
# 5/5 [==============================] - 2s 384ms/step - loss: 0.0244
# Epoch 497/500
# 5/5 [==============================] - 2s 377ms/step - loss: 0.0242
# Epoch 498/500
# 5/5 [==============================] - 2s 379ms/step - loss: 0.0241
# Epoch 499/500
# 5/5 [==============================] - 2s 374ms/step - loss: 0.0244
# Epoch 500/500
# 5/5 [==============================] - 2s 376ms/step - loss: 0.0243

# %% [markdown]
# ## Inference models

# %%
def make_inference_models():
    
    encoder_model = tf.keras.models.Model(encoder_inputs, encoder_states)
    
    decoder_state_input_h = tf.keras.layers.Input(shape=(256,))
    decoder_state_input_c = tf.keras.layers.Input(shape=(256,))
    
    decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
    
    decoder_outputs, state_h, state_c = decoder_lstm(
        decoder_embedding , initial_state=decoder_states_inputs)
    decoder_states = [state_h, state_c]
    decoder_outputs = decoder_dense(decoder_outputs)
    decoder_model = tf.keras.models.Model(
        [decoder_inputs] + decoder_states_inputs,
        [decoder_outputs] + decoder_states)
    
    return encoder_model , decoder_model

# %%
import tensorflow as tf
def str_to_tokens( sentence : str ):
    words = sentence.lower().split()
    tokens_list = list()
    for word in words:
        tokens_list.append( input_word_dict[ word ] ) 
    return preprocessing.sequence.pad_sequences( [tokens_list] , maxlen=max_input_length , padding='post')

# %%
enc_model , dec_model = make_inference_models()
for epoch in range( encoder_input_data.shape[0] ):
    states_values = enc_model.predict( str_to_tokens( input( 'User: ' ) ) )
    empty_target_seq = np.zeros( ( 1 , 1 ) )
    empty_target_seq[0, 0] = output_word_dict['start']
    stop_condition = False
    decoded_translation = ''
    while not stop_condition :
        dec_outputs , h , c = dec_model.predict([ empty_target_seq ] + states_values )
        sampled_word_index = np.argmax( dec_outputs[0, -1, :] )
        sampled_word = None
        for word , index in output_word_dict.items() :
            if sampled_word_index == index :
                decoded_translation += ' {}'.format( word )
                sampled_word = word
        
        if sampled_word == 'end' or len(decoded_translation.split()) > max_output_length:
            stop_condition = True
            
        empty_target_seq = np.zeros( ( 1 , 1 ) )  
        empty_target_seq[ 0 , 0 ] = sampled_word_index
        states_values = [ h , c ] 

    print( "Bot:" +decoded_translation.replace(' end', '') )
    print()
# Out:
# 1/1 [==============================] - 0s 397ms/step
# 1/1 [==============================] - 0s 263ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# Bot: i am interested in all kinds of things we can talk about anything
#
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# Bot: i have read just about everything in project gutenberg
